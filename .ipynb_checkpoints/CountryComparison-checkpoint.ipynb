# %%
#bringing in dependencies
import pandas as pd
import glob
import os
import csv
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
import sys
import json
import re

# %%
#bringing in global chart
globalchart = os.path.join("WeeklyCharts", "Global Weekly Chart.csv")

#making it readable with pandas library
globalchart_df = pd.read_csv(globalchart)
globalchart_df.head()
# Out:
#   Unnamed: 0                        Unnamed: 1  Unnamed: 2  \
# 0   Position                        Track Name      Artist
# 1          1      ROCKSTAR (feat. Roddy Ricch)      DaBaby
# 2          2  Savage Love (Laxed - Siren Beat)   Jawsh 685
# 3          3                   Blinding Lights  The Weeknd
# 4          4       Come & Go (with Marshmello)  Juice WRLD
#
#   Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                            Streams
# 1                                           36999793
# 2                                           34262951
# 3                                           30727192
# 4                                           30027587
#
#                                           Unnamed: 4
# 0                                                URL
# 1  https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 2  https://open.spotify.com/track/1xQ6trAsedVPCdb...
# 3  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# 4  https://open.spotify.com/track/7y7w4tl4MaRC2UM...

# %%
#cleaning up chart a bit by removing unnecessary columns and correcting headers
globalchart_clean_df = globalchart_df.drop(columns=['Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.', 'Unnamed: 4'])
globalchart_clean_df.rename(columns = {'Unnamed: 0' : 'Global - Rank', 'Unnamed: 1' : 'Name of Track', 'Unnamed: 2' : 'Artist'}, inplace=True)


globalchart_clean_df
# Out:
#     Global - Rank                      Name of Track       Artist
# 0        Position                         Track Name       Artist
# 1               1       ROCKSTAR (feat. Roddy Ricch)       DaBaby
# 2               2   Savage Love (Laxed - Siren Beat)    Jawsh 685
# 3               3                    Blinding Lights   The Weeknd
# 4               4        Come & Go (with Marshmello)   Juice WRLD
# ..            ...                                ...          ...
# 196           196  El Mismo Aire - con Pablo Alborán       Camilo
# 197           197                             Lalala          Y2K
# 198           198                      Sigues Con El  Dímelo Flow
# 199           199                  Something Special    Pop Smoke
# 200           200                         Como Llora     Juanfran
#
# [201 rows x 3 columns]

# %%
#Now working on making the data more readable in the files so that we can look at it holistically

#accessing all files in folder
allFiles = glob.glob(os.path.join("WeeklyCharts","*.csv"))

#adding them to a list
chart_list = []

for file in allFiles:
    chart_list.append(file)
chart_list.sort()


#cleaning up names
country_list = []

for country in chart_list:
    name = country
    y = re.split('/| Weekly C|', name)
    country_list.append(y[1])
country_list.sort()
#country_list

# %%
#Now let's repeat the process we did with the global chart with all the files
i = 0
total_chart_df = pd.DataFrame()
total_chart_df = pd.concat([globalchart_clean_df, total_chart_df], axis = 1)
for country in chart_list:
    
    country_df = pd.read_csv(country)
    country_df = country_df.drop(columns=['Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.', 'Unnamed: 4'])
    country_df = country_df.rename(columns = {'Unnamed: 0' : country_list[i] + ' - Rank', 'Unnamed: 1' : 'Name of Track', 'Unnamed: 2' : 'Artist'})
 
    i = i + 1
    total_chart_df = pd.concat([total_chart_df, country_df], axis=1)
    
#removing duplicate labelings
total_chart_df = total_chart_df.iloc[1:]

#final chart
total_chart_df
# Out:
#     Global - Rank                      Name of Track        Artist  \
# 1               1       ROCKSTAR (feat. Roddy Ricch)        DaBaby
# 2               2   Savage Love (Laxed - Siren Beat)     Jawsh 685
# 3               3                    Blinding Lights    The Weeknd
# 4               4        Come & Go (with Marshmello)    Juice WRLD
# 5               5                   Watermelon Sugar  Harry Styles
# ..            ...                                ...           ...
# 196           196  El Mismo Aire - con Pablo Alborán        Camilo
# 197           197                             Lalala           Y2K
# 198           198                      Sigues Con El   Dímelo Flow
# 199           199                  Something Special     Pop Smoke
# 200           200                         Como Llora      Juanfran
#
#     Argentina - Rank       Name of Track           Artist Australia - Rank  \
# 1                  1  La Jeepeta - Remix       Nio Garcia                1
# 2                  2            Caramelo            Ozuna                2
# 3                  3            Relación             Sech                3
# 4                  4      Tattoo - Remix   Rauw Alejandro                4
# 5                  5       La Curiosidad      Jay Wheeler                5
# ..               ...                 ...              ...              ...
# 196              196          Con Altura          ROSALÍA              196
# 197              197          Supalonely            BENEE              197
# 198              198          Falta Amor  Sebastian Yatra              198
# 199              199        Perdidamente    Maria Becerra              199
# 200              200  Toda Remix - Remix        Alex Rose              200
#
#                                   Name of Track           Artist  \
# 1                  ROCKSTAR (feat. Roddy Ricch)           DaBaby
# 2              Savage Love (Laxed - Siren Beat)        Jawsh 685
# 3                   Come & Go (with Marshmello)       Juice WRLD
# 4                         Roses - Imanbek Remix        SAINt JHN
# 5                              Watermelon Sugar     Harry Styles
# ..                                          ...              ...
# 196                     Turn Me On (feat. Vula)            Riton
# 197                High Fashion (feat. Mustard)      Roddy Ricch
# 198  I Wanna Dance with Somebody (Who Loves Me)  Whitney Houston
# 199                          Deep End Freestyle    Sleepy Hallow
# 200                                Chasing Cars      Snow Patrol
#
#     Austria - Rank  ...         Artist USA - Rank  \
# 1                1  ...         DaBaby          1
# 2                2  ...      Jawsh 685          2
# 3                3  ...     Juice WRLD          3
# 4                4  ...   Harry Styles          4
# 5                5  ...          Topic          5
# ..             ...  ...            ...        ...
# 196            196  ...           TOTO        196
# 197            197  ...  Calvin Harris        197
# 198            198  ...     Marshmello        198
# 199            199  ...            NSG        199
# 200            200  ...  Billie Eilish        200
#
#                                          Name of Track       Artist  \
# 1                          Come & Go (with Marshmello)   Juice WRLD
# 2                                         Wishing Well   Juice WRLD
# 3                                        Conversations   Juice WRLD
# 4                         Life's A Mess (feat. Halsey)   Juice WRLD
# 5    Hate The Other Side (with Marshmello & The Kid...   Juice WRLD
# ..                                                 ...          ...
# 196                       Like That (feat. Gucci Mane)     Doja Cat
# 197                                     No Role Modelz      J. Cole
# 198                                            No Idea  Don Toliver
# 199                                         Better Now  Post Malone
# 200                                         Gimme Love         Joji
#
#     Uruguay - Rank                       Name of Track          Artist  \
# 1                1                  La Jeepeta - Remix      Nio Garcia
# 2                2                            Caramelo           Ozuna
# 3                3                       La Curiosidad     Jay Wheeler
# 4                4                            Relación            Sech
# 5                5                      Tattoo - Remix  Rauw Alejandro
# ..             ...                                 ...             ...
# 196            196                     Una y Mil Veces             MYA
# 197            197                           Mala Fama     Danna Paola
# 198            198                           Honey Boo            CNCO
# 199            199                            Años Luz    Nicki Nicole
# 200            200  DANI: Bzrp Music Sessions, Vol. 24        Bizarrap
#
#     Vietnam - Rank                                    Name of Track  \
# 1                1                      Bigcityboi (feat. Touliver)
# 2                2                               CÓ CHẮC YÊU LÀ ĐÂY
# 3                3                                How You Like That
# 4                4                           từ chối nhẹ nhàng thôi
# 5                5                                       Một Cú Lừa
# ..             ...                                              ...
# 196            196                               Buồn Làm Chi Em Ơi
# 197            197                                         Liệu Giờ
# 198            198  ME! (feat. Brendon Urie of Panic! At The Disco)
# 199            199                                          Túy Họa
# 200            200                                           Cảm ơn
#
#             Artist
# 1             Binz
# 2    Sơn Tùng M-TP
# 3        BLACKPINK
# 4      Bich Phuong
# 5      Bich Phuong
# ..             ...
# 196       Hoài Lâm
# 197             2T
# 198   Taylor Swift
# 199          K-ICM
# 200            Đen
#
# [200 rows x 192 columns]

# %%
#Now that we have our data compiled and sorted, we can begin looking at it statistically

#total_chart_df.describe()

#total_chart_df[' '] = pd.to_numeric(df[' '])
